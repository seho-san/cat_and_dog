# %%
import pickle

# %%
X=pickle.load(open('X.pkl','rb'))
y=pickle.load(open('y.pkl','rb'))

# %%
X
# Out:
# array([[[[ 52,  45,  48],
#          [ 54,  48,  48],
#          [ 45,  40,  37],
#          ...,
#          [158, 158, 158],
#          [157, 157, 157],
#          [157, 156, 158]],
#
#         [[ 52,  45,  48],
#          [ 54,  48,  48],
#          [ 60,  55,  52],
#          ...,
#          [154, 154, 154],
#          [157, 157, 157],
#          [155, 155, 155]],
#
#         [[ 53,  46,  49],
#          [ 55,  49,  49],
#          [ 46,  41,  38],
#          ...,
#          [154, 154, 154],
#          [155, 155, 155],
#          [157, 157, 156]],
#
#         ...,
#
#         [[ 44,  43,  38],
#          [ 61,  60,  56],
#          [ 56,  54,  55],
#          ...,
#          [108, 100,  81],
#          [121, 113,  94],
#          [112, 104,  85]],
#
#         [[ 51,  46,  49],
#          [ 26,  21,  27],
#          [ 35,  30,  37],
#          ...,
#          [121, 113,  94],
#          [110, 102,  83],
#          [118, 110,  90]],
#
#         [[ 44,  37,  45],
#          [ 43,  35,  46],
#          [ 43,  35,  50],
#          ...,
#          [117, 106,  85],
#          [123, 117,  95],
#          [109, 104,  82]]],
#
#
#        [[[ 60,  54,  54],
#          [ 87,  81,  81],
#          [ 99,  93,  93],
#          ...,
#          [ 66,  58,  55],
#          [ 60,  53,  45],
#          [ 63,  56,  48]],
#
#         [[ 82,  76,  76],
#          [ 63,  57,  57],
#          [101,  95,  95],
#          ...,
#          [ 91,  83,  80],
#          [ 61,  54,  46],
#          [ 43,  36,  28]],
#
#         [[ 92,  86,  86],
#          [ 50,  44,  44],
#          [101,  95,  95],
#          ...,
#          [ 99,  91,  88],
#          [ 72,  65,  57],
#          [ 49,  42,  34]],
#
#         ...,
#
#         [[178, 172, 172],
#          [179, 173, 175],
#          [182, 176, 180],
#          ...,
#          [173, 173, 183],
#          [178, 178, 180],
#          [177, 177, 179]],
#
#         [[179, 173, 173],
#          [178, 172, 174],
#          [177, 171, 175],
#          ...,
#          [180, 179, 187],
#          [178, 178, 180],
#          [180, 180, 182]],
#
#         [[180, 174, 174],
#          [182, 176, 178],
#          [180, 174, 178],
#          ...,
#          [176, 173, 180],
#          [179, 179, 181],
#          [180, 180, 182]]],
#
#
#        [[[156, 152, 140],
#          [159, 155, 143],
#          [155, 151, 139],
#          ...,
#          [129, 125, 113],
#          [140, 136, 124],
#          [142, 136, 124]],
#
#         [[158, 154, 142],
#          [151, 147, 135],
#          [152, 148, 136],
#          ...,
#          [129, 125, 113],
#          [141, 137, 125],
#          [142, 136, 124]],
#
#         [[155, 151, 139],
#          [155, 151, 139],
#          [154, 150, 138],
#          ...,
#          [131, 127, 115],
#          [143, 139, 127],
#          [142, 140, 127]],
#
#         ...,
#
#         [[161, 157, 145],
#          [156, 152, 140],
#          [163, 159, 147],
#          ...,
#          [ 39,  38,  44],
#          [ 49,  42,  32],
#          [ 88,  81,  63]],
#
#         [[159, 155, 143],
#          [162, 158, 146],
#          [157, 153, 141],
#          ...,
#          [ 28,  30,  27],
#          [ 40,  41,  36],
#          [ 71,  61,  52]],
#
#         [[159, 155, 143],
#          [158, 154, 142],
#          [160, 156, 144],
#          ...,
#          [ 58,  60,  57],
#          [ 56,  57,  51],
#          [ 36,  26,  17]]],
#
#
#        ...,
#
#
#        [[[ 68,  81,  89],
#          [ 77,  89,  97],
#          [ 76,  89,  97],
#          ...,
#          [200, 215, 234],
#          [203, 218, 237],
#          [198, 213, 232]],
#
#         [[ 67,  80,  88],
#          [ 75,  88,  96],
#          [ 77,  90,  97],
#          ...,
#          [198, 213, 234],
#          [198, 213, 234],
#          [197, 211, 233]],
#
#         [[ 63,  76,  84],
#          [ 73,  86,  94],
#          [ 72,  85,  93],
#          ...,
#          [186, 201, 224],
#          [188, 203, 226],
#          [187, 202, 225]],
#
#         ...,
#
#         [[180, 214, 224],
#          [178, 215, 224],
#          [181, 221, 229],
#          ...,
#          [153, 182, 188],
#          [144, 173, 179],
#          [146, 169, 177]],
#
#         [[170, 207, 216],
#          [181, 219, 228],
#          [176, 215, 223],
#          ...,
#          [154, 182, 188],
#          [171, 196, 203],
#          [145, 169, 173]],
#
#         [[170, 208, 217],
#          [172, 210, 219],
#          [175, 213, 222],
#          ...,
#          [156, 183, 190],
#          [151, 174, 182],
#          [147, 171, 175]]],
#
#
#        [[[ 89,  77,  71],
#          [ 93,  83,  74],
#          [ 92,  83,  71],
#          ...,
#          [ 61,  54,  45],
#          [ 69,  63,  54],
#          [ 77,  70,  62]],
#
#         [[100,  89,  83],
#          [ 87,  77,  68],
#          [ 92,  82,  70],
#          ...,
#          [ 67,  60,  52],
#          [ 68,  61,  53],
#          [ 69,  62,  54]],
#
#         [[ 79,  68,  62],
#          [ 87,  77,  68],
#          [104,  94,  82],
#          ...,
#          [ 72,  65,  57],
#          [ 75,  68,  60],
#          [ 72,  65,  57]],
#
#         ...,
#
#         [[138, 127, 121],
#          [150, 139, 134],
#          [145, 134, 128],
#          ...,
#          [253, 251, 252],
#          [253, 251, 252],
#          [252, 252, 252]],
#
#         [[147, 136, 131],
#          [137, 126, 120],
#          [138, 127, 121],
#          ...,
#          [253, 251, 252],
#          [253, 251, 252],
#          [252, 252, 252]],
#
#         [[129, 118, 112],
#          [130, 120, 111],
#          [132, 122, 111],
#          ...,
#          [254, 252, 253],
#          [253, 251, 252],
#          [253, 251, 254]]],
#
#
#        [[[ 58,  37,   6],
#          [ 60,  39,   8],
#          [ 64,  43,  12],
#          ...,
#          [194, 168, 144],
#          [195, 169, 144],
#          [192, 168, 144]],
#
#         [[ 60,  39,   8],
#          [ 62,  41,  10],
#          [ 64,  43,  12],
#          ...,
#          [199, 173, 148],
#          [197, 171, 146],
#          [196, 172, 148]],
#
#         [[ 61,  40,   9],
#          [ 63,  42,  11],
#          [ 64,  43,  12],
#          ...,
#          [198, 172, 147],
#          [201, 175, 150],
#          [198, 172, 149]],
#
#         ...,
#
#         [[162, 131, 100],
#          [164, 134, 100],
#          [172, 142, 104],
#          ...,
#          [160, 128, 105],
#          [155, 122, 103],
#          [157, 124, 105]],
#
#         [[161, 130,  99],
#          [166, 136, 102],
#          [166, 136,  98],
#          ...,
#          [158, 125, 106],
#          [154, 121, 104],
#          [152, 121, 103]],
#
#         [[159, 128,  97],
#          [165, 135, 101],
#          [165, 135,  97],
#          ...,
#          [153, 120, 101],
#          [153, 120, 103],
#          [148, 117,  99]]]], dtype=uint8)

# %%
y
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
X=X/255

# %%
X.shape
# Out:
# (23000, 100, 100, 3)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model=Sequential()

model.add(Conv2D(64,(3,3),activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64,(3,3),activation = 'relu'))
model.add(MaxPooling2D((2,2)))


model.add(Flatten())

model.add(Dense(128,input_shape = X.shape[1:],activation = 'relu'))

model.add(Dense(2,activation = 'softmax'))

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(X,y,epochs = 5, validation_split=0.1)
# Out:
# Epoch 1/5
# 647/647 [==============================] - 79s 122ms/step - loss: 0.6552 - accuracy: 0.6157 - val_loss: 0.6144 - val_accuracy: 0.6835
# Epoch 2/5
# 647/647 [==============================] - 76s 117ms/step - loss: 0.5654 - accuracy: 0.7124 - val_loss: 0.5029 - val_accuracy: 0.7487
# Epoch 3/5
# 647/647 [==============================] - 76s 118ms/step - loss: 0.4754 - accuracy: 0.7731 - val_loss: 0.4487 - val_accuracy: 0.7848
# Epoch 4/5
# 647/647 [==============================] - 78s 121ms/step - loss: 0.3753 - accuracy: 0.8304 - val_loss: 0.4504 - val_accuracy: 0.7935
# Epoch 5/5
# 647/647 [==============================] - 76s 118ms/step - loss: 0.2527 - accuracy: 0.8926 - val_loss: 0.5289 - val_accuracy: 0.7930
